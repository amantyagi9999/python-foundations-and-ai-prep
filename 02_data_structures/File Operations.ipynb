# %%
# Writing to files

with open('/Users/amant/Desktop/AI Transition/python-foundations-and-ai-prep/02_data_structures/output.txt', "w") as f:
    content = f.write("Welcome to AI world. Start your AI Journey today. keep going.\n")
print(content)
# Out:
# 62

# %%
# Append to file
with open('/Users/amant/Desktop/AI Transition/python-foundations-and-ai-prep/02_data_structures/output.txt', "a") as f:
    content = f.write("New Line Added!\n")
print(content)
# Out:
# 16

# %%
with open('/Users/amant/Desktop/AI Transition/python-foundations-and-ai-prep/02_data_structures/output.txt', "r") as f:
    content = f.read()
print(content)
# Out:
# Welcome to AI world. Start your AI Journey today. keep going.
# New Line Added!

# %%
#Read Line by Line

with open('/Users/amant/Desktop/AI Transition/python-foundations-and-ai-prep/02_data_structures/output.txt', "r") as f:
    for line in f:
        print(line.strip())
# Out:
# Welcome to AI world. Start your AI Journey today. keep going.
# New Line Added!
# New Line Added!

# %%
# Read all line as List
with open('/Users/amant/Desktop/AI Transition/python-foundations-and-ai-prep/02_data_structures/output.txt', "r") as f:
    lines = f.readlines()
print(lines)
# Out:
# ['Welcome to AI world. Start your AI Journey today. keep going.\n', 'New Line Added!\n', 'New Line Added!\n']

# %%
# Parse File content

import csv

with open('/Users/amant/Desktop/AI Transition/python-foundations-and-ai-prep/02_data_structures/TestData.csv') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['id', 'name', 'age', 'city']
# ['1', 'Aman', '19', 'Delhi']
# ['2', 'Shubham', '21', 'Ghaziabad']
# ['3', 'Priya', '67', 'Hyderabad']
# ['4', 'Roshan', '45', 'Banglore']
# ['5', 'Deepu', '23', 'Pune']

# %%
# Parse csv into dict

import csv

with open('/Users/amant/Desktop/AI Transition/python-foundations-and-ai-prep/02_data_structures/TestData.csv') as file:
    reader = csv.DictReader(file)
    for row in reader:
        print(row["id"], row["name"])
# Out:
# 1 Aman
# 2 Shubham
# 3 Priya
# 4 Roshan
# 5 Deepu

# %%
#Parse JSON File

import json

with open("/Users/amant/Desktop/AI Transition/python-foundations-and-ai-prep/02_data_structures/TestJson") as f:
    data = json.load(f)

print(data)
# Out:
# [{'id': 1, 'name': 'Aman', 'city': 'Delhi'}, {'id': 2, 'name': 'Rohit', 'city': 'Mumbai'}]

# %%
# Parse Text with Split

with open("/Users/amant/Desktop/AI Transition/python-foundations-and-ai-prep/02_data_structures/TestJson") as f:
    for line in f:
        parts = line.split(";")
        print(parts)
# Out:
# ['[\n']
# ['  {\n']
# ['    "id": 1,\n']
# ['    "name": "Aman",\n']
# ['    "city": "Delhi"\n']
# ['  },\n']
# ['  {\n']
# ['    "id": 2,\n']
# ['    "name": "Rohit",\n']
# ['    "city": "Mumbai"\n']
# ['  }\n']
# [']\n']

# %%
# Checking file Existence

import os

if os.path.exists("/Users/amant/Desktop/AI Transition/python-foundations-and-ai-prep/02_data_structures/TestJson"):
    print("File exists")
else:
    print("File not found")
# Out:
# File exists

# %%
# Delete file

import os

if os.path.exists("old.txt"):
    os.remove("old.txt")

# %%
# Create Directory

import os

os.makedirs("new_folder", exist_ok=True)

# List Files in a Directory

files = os.listdir(".")
print(files)
# Out:
# ['new_folder', '.DS_Store', 'TestJson', 'File Operations.ipynb', 'TestData.csv', '.ipynb_checkpoints', 'output.txt', 'Data Structure.ipynb']

# %%
# Read Binary

with open("/Users/amant/Desktop/AI Transition/python-foundations-and-ai-prep/02_data_structures/sampleImg.jpg", "rb") as f:
    data = f.read()

    print(data)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x01,\x01,\x00\x00\xff\xe1\x00\x8fExif\x00\x00II*\x00\x08\x00\x00\x00\x04\x00\x0e\x01\x02\x003\x00\x00\x00>\x00\x00\x00\x98\x82\x02\x00\x06\x00\x00\x00q\x00\x00\x00\x1a\x01\x05\x00\x01\x00\x00\x00w\x00\x00\x00\x1b\x01\x05\x00\x01\x00\x00\x00\x7f\x00\x00\x00\x00\x00\x00\x00http://kuaijibbs.com/istockphoto/banner/zhuce1.jpg hh5800,\x01\x00\x00\x01\x00\x00\x00,\x01\x00\x00\x01\x00\x00\x00\xff\xe1\x05\x95http://ns.adobe.com/xap/1.0/\x00<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\n<x:xmpmeta xmlns:x="adobe:ns:meta/">\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">\n\t\t<rdf:Description rdf:about="" xmlns:photoshop="http://ns.adobe.com/photoshop/1.0/" xmlns:Iptc4xmpCore="http://iptc.org/std/Iptc4xmpCore/1.0/xmlns/"   xmlns:GettyImagesGIFT="http://xmp.gettyimages.com/gift/1.0/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:plus="http://ns.useplus.org/ldf/xmp/1.0/"  xmlns:iptcExt="http://iptc.org/std/Ip
# ...
